# %% [markdown]
# # Visualisation partie 2
#
# L'objectif de ce TD est de :
# - Créer son premier widget
# - Ajouter des éléments d'interactivité à un graphique Plotly
# - transfomer le notebook de visualisation interactive en webapp (application web) avec Voilà
# - déployer et partager cette application web avec ngrok

# %% [markdown]
# # 1) Création d'un premier widget

# %% [markdown]
# a) Installation de la librairie Pywi

# %%
import sys
# !{sys.executable} -m pip install ipywidgets statsmodels
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (8.1.8)
# Requirement already satisfied: statsmodels in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (0.14.6)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipywidgets) (9.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from statsmodels) (2.4.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from statsmodels) (1.17.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from statsmodels) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)

# %% [markdown]
# b) Exécutez le code ci-dessous pour importer la librairie et la renommer widgets. On utilsera

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# c) La liste complète des widgets disponible est disponible à [cette adresse](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html).
#
# A l'aide de cette documentation, construisez une variable `my_int_slider` qui contiendra un widget "IntSlider" avec 5 comme valeur par défaut, 1 en minimum et 20 en maximum. On pourra laisser step égal à 1 comme niveau d'incrément.
#
# Utilisez la fonction "display" pour l'afficher.

# %%
# IntSlider : curseur pour choisir un entier entre min et max
my_int_slider = widgets.IntSlider(value=5, min=1, max=20, step=1)

display(my_int_slider)
# Out:
# IntSlider(value=5, max=20, min=1)

# %% [markdown]
# d) A quoi corresponnd le résultat de cette opération ?

# %%
my_int_slider.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'behavior',
#  'continuous_update',
#  'description',
#  'description_allow_html',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'tabbable',
#  'tooltip',
#  'value']

# %% [markdown]
# e) En déduire comment afficher la valeur du slider.
#
# Faites varier la valeur du slider et vérifier qu'en exécutant de nouveau la ligne de code, la valeur a bien changé.

# %%
# .value contient la valeur actuelle du widget (change quand on bouge le curseur)
my_int_slider.value
# Out:
# 5

# %% [markdown]
# # 2) Création d'un User Form

# %% [markdown]
# Les widgets peuvent servir à créer des user forms pour des utilisateurs finaux.
#
# Cet exercice a pour but de construire un outil qui permet de sélectionner de sélectionner un indice boursier pour afficher un scatter plot avec l'indice d'apple AAPL.

# %% [markdown]
# a) Importez les librairies suivantes

# %%
import pandas as pd 
import plotly.express as px
from ipywidgets import interact, interactive, fixed, interactive_output
import io

# %% [markdown]
# b) Dans une variable `my_upload_widget`, créez un widget de type Fileupload qui accepte l'extension .csv et un seul fichier à la fois. Puis testez l'import de ce fichier [csv exemple](https://drive.google.com/file/d/1bWMYHBP6pnxB-sztTyRe8gGMszD0GOp4/view?usp=sharing).

# %%
# FileUpload : widget pour importer un fichier depuis l'ordinateur
# accept=".csv" limite aux CSV, multiple=False = un seul fichier à la fois
my_upload_widget = widgets.FileUpload(accept=".csv", multiple=False)

display(my_upload_widget)
# Out:
# FileUpload(value=(), accept='.csv', description='Upload')

# %% [markdown]
# c) Le données en sortie sont un peu difficile à extraire.
#
# Exécutez le code ci-dessous pour gagner du temps et posez vos questions au professeur.

# %%
df = pd.read_csv(io.BytesIO(list(my_upload_widget.value)[0]["content"]))
df
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %% [markdown]
# d) Représentez dans un graphique Plotly Scatter les donnnées de GOOG versus APPL avec une courbe de tendance (trendlines='ols') pour voir la corrélation entre ces deux indices.

# %%
# Scatter plot : GOOG en x, AAPL en y, avec droite de tendance (corrélation)
fig = px.scatter(df, x="GOOG", y="AAPL", trendline="ols")
fig.show()

# %% [markdown]
# e) Créez une fonction `financial_scatter_widget` qui prendra en entrée les paramètres df, x et y, elle affichera le graphique créé précédemment pour les noms de colonnes x et y.

# %%
def financial_scatter_widget(df, x=None, y=None):
    # Même graphique que d) mais paramétré avec x et y
    fig = px.scatter(df, x=x, y=y, trendline="ols")
    fig.show()

financial_scatter_widget(df, x="GOOG", y="AAPL")

# %% [markdown]
# f) L'idée est de donner la main à l'utilisateur pour choisir quel indice il souhaite vérifier la correlation avec l'indice APPL.
#
# Créez un widget de type Dropdown, qui permettra de sélectionner le nom d'une colonne du DataFrame créé.

# %%
# Dropdown : menu déroulant avec les noms de colonnes du DataFrame
x_dropdown = widgets.Dropdown(
    options=df.columns.tolist(),
    value='AAPL',
    description='AAPL vs ',
    style= {'description_width': 'initial'},
    disabled=False,
)
display(x_dropdown)
# Out:
# Dropdown(description='AAPL vs ', index=2, options=('date', 'GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT'), styl…

# %% [markdown]
# g) A l'aide de la fonction `interact()` de widgets, faites exécutez la fonction `financial_scatter_widget` en fonction de la colonne choisie.
#
# On fixera les paramètres `df`=Le DataFrame récupéré de l'upload  et `y`="APPL" à l'aide de la fonction `fixed()`.

# %%
# interact() connecte le widget au graphique : quand on change le dropdown, le graph se met à jour
# fixed() : paramètres qu'on ne veut pas modifier (df et y restent fixes)
widgets.interact(
    financial_scatter_widget,
    df=fixed(df),
    x=x_dropdown,
    y=fixed("AAPL")
)
# Out:
# interactive(children=(Dropdown(description='AAPL vs ', index=2, options=('date', 'GOOG', 'AAPL', 'AMZN', 'FB',…
# <function __main__.financial_scatter_widget(df, x=None, y=None)>

# %% [markdown]
# # 3) Réalisation du Dashboard restaurateur

# %% [markdown]
# Nous allons reprendre les visualisations faites au dernier TP et y ajouter deux éléments d'interaction, l'id du restaurant et les dates de la période sélectionnée.

# %% [markdown]
# Done

# %% [markdown]
# a) Nous allons reprendre les données du TP précédent. Si besoin, vous pouvez de nouveau les téléchargez à [cette adresse](https://drive.google.com/file/d/1tSA-l-ziWLk90iX48eHne_8aPfx8braI/view?usp=sharing).

# %% [markdown]
# b) Exécutez le code suivant de preprocessing des données.

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interactive_output
from IPython.display import display

df = pd.read_csv("Tiller_order_data.csv", low_memory=False)

# Transforme les dates en format datetime
df["date_opened"] = pd.to_datetime(df["date_opened"])
df["date_closed"] = pd.to_datetime(df["date_closed"])

# Mettre en index la date d'ouverture de commande
df = df.set_index(df["date_opened"])

# %%
df
# Out:
#                            id_order  id_store  id_table  id_waiter  \
# date_opened
# 2019-01-12 13:02:17+00:00  55538867      8052       NaN        NaN
# 2019-01-16 19:39:09+00:00  56035309      8052       NaN        NaN
# 2019-01-12 14:18:46+00:00  55550051      8052       NaN        NaN
# 2019-01-24 17:49:12+00:00  57000119      8052       NaN    16199.0
# 2019-01-12 15:25:06+00:00  55558817      8052       NaN        NaN
# ...                             ...       ...       ...        ...
# 2019-02-28 13:13:21+00:00  61630471      4542       NaN        NaN
# 2019-06-11 11:08:01+00:00  76772730      4542       NaN        NaN
# 2019-06-17 10:30:50+00:00  77799227      4542       NaN        NaN
# 2019-02-21 11:50:58+00:00  60627160      4542       NaN        NaN
# 2019-09-18 11:32:35+00:00  93223821      4542       NaN        NaN
#
#                            id_customer                           id_external  \
# date_opened
# 2019-01-12 13:02:17+00:00          NaN  0425716B-EFF4-41CA-AEA1-839104F36833
# 2019-01-16 19:39:09+00:00          NaN  75E41FE2-64FF-41D3-954C-A7DE4AA887EF
# 2019-01-12 14:18:46+00:00          NaN  F6051A05-C9AC-4033-BF72-BB5149B8F439
# 2019-01-24 17:49:12+00:00          NaN  B8BEEC66-1C10-48A0-B4D5-035CB5EEFE62
# 2019-01-12 15:25:06+00:00          NaN  17F0533C-2FF1-4FC5-A50D-12704C7B7A4B
# ...                                ...                                   ...
# 2019-02-28 13:13:21+00:00          NaN  C4A0AFD8-FBD7-4740-A48B-4890F46E43E2
# 2019-06-11 11:08:01+00:00          NaN  95A17B0B-22AE-43A1-8BEB-B105BF337655
# 2019-06-17 10:30:50+00:00          NaN  0E5D4843-7EA3-4D9E-9490-EB9717A0220F
# 2019-02-21 11:50:58+00:00          NaN  CE760A3B-4464-462A-AA2C-CCFEB88EEC39
# 2019-09-18 11:32:35+00:00          NaN  F004A307-C7C9-4508-A587-49ED5CF8F156
#
#                            id_device               date_opened  \
# date_opened
# 2019-01-12 13:02:17+00:00    15327.0 2019-01-12 13:02:17+00:00
# 2019-01-16 19:39:09+00:00    15327.0 2019-01-16 19:39:09+00:00
# 2019-01-12 14:18:46+00:00    15327.0 2019-01-12 14:18:46+00:00
# 2019-01-24 17:49:12+00:00    15327.0 2019-01-24 17:49:12+00:00
# 2019-01-12 15:25:06+00:00    15327.0 2019-01-12 15:25:06+00:00
# ...                              ...                       ...
# 2019-02-28 13:13:21+00:00     7411.0 2019-02-28 13:13:21+00:00
# 2019-06-11 11:08:01+00:00     7411.0 2019-06-11 11:08:01+00:00
# 2019-06-17 10:30:50+00:00     7411.0 2019-06-17 10:30:50+00:00
# 2019-02-21 11:50:58+00:00     7411.0 2019-02-21 11:50:58+00:00
# 2019-09-18 11:32:35+00:00     7411.0 2019-09-18 11:32:35+00:00
#
#                                         date_closed  \
# date_opened
# 2019-01-12 13:02:17+00:00 2019-01-12 19:58:38+00:00
# 2019-01-16 19:39:09+00:00 2019-01-16 22:10:50+00:00
# 2019-01-12 14:18:46+00:00 2019-01-12 19:50:32+00:00
# 2019-01-24 17:49:12+00:00 2019-01-24 21:58:59+00:00
# 2019-01-12 15:25:06+00:00 2019-01-12 19:21:03+00:00
# ...                                             ...
# 2019-02-28 13:13:21+00:00 2019-02-28 13:38:45+00:00
# 2019-06-11 11:08:01+00:00 2019-06-11 11:10:26+00:00
# 2019-06-17 10:30:50+00:00 2019-06-17 10:32:45+00:00
# 2019-02-21 11:50:58+00:00 2019-02-21 11:51:56+00:00
# 2019-09-18 11:32:35+00:00 2019-09-18 11:39:38+00:00
#
#                                              dim_name dim_status  dim_type  \
# date_opened
# 2019-01-12 13:02:17+00:00                     vincent     CLOSED         1
# 2019-01-16 19:39:09+00:00  frere et soeur avec pierre     CLOSED         1
# 2019-01-12 14:18:46+00:00                      rachel     CLOSED         1
# 2019-01-24 17:49:12+00:00                  Groupe PEL     CLOSED         1
# 2019-01-12 15:25:06+00:00                remi et date     CLOSED         1
# ...                                               ...        ...       ...
# 2019-02-28 13:13:21+00:00                         NaN     CLOSED         1
# 2019-06-11 11:08:01+00:00                         NaN     CLOSED         1
# 2019-06-17 10:30:50+00:00                         NaN     CLOSED         1
# 2019-02-21 11:50:58+00:00                         NaN     CLOSED         1
# 2019-09-18 11:32:35+00:00                         NaN     CLOSED         1
#
#                           dim_comment    dim_source  m_nb_customer  \
# date_opened
# 2019-01-12 13:02:17+00:00         NaN   Tiller iPAD              1
# 2019-01-16 19:39:09+00:00         NaN   Tiller iPAD              2
# 2019-01-12 14:18:46+00:00         NaN   Tiller iPAD              1
# 2019-01-24 17:49:12+00:00         NaN  tiller-order              3
# 2019-01-12 15:25:06+00:00         NaN   Tiller iPAD              2
# ...                               ...           ...            ...
# 2019-02-28 13:13:21+00:00         NaN   Tiller iPAD              1
# 2019-06-11 11:08:01+00:00         NaN   Tiller iPAD              1
# 2019-06-17 10:30:50+00:00         NaN   Tiller iPAD              1
# 2019-02-21 11:50:58+00:00         NaN   Tiller iPAD              1
# 2019-09-18 11:32:35+00:00         NaN   Tiller iPAD              1
#
#                            m_cached_payed  m_cached_price
# date_opened
# 2019-01-12 13:02:17+00:00            45.5            45.5
# 2019-01-16 19:39:09+00:00            49.8            49.8
# 2019-01-12 14:18:46+00:00            27.4            27.4
# 2019-01-24 17:49:12+00:00            60.0            60.0
# 2019-01-12 15:25:06+00:00            39.9            39.9
# ...                                   ...             ...
# 2019-02-28 13:13:21+00:00            23.0            23.0
# 2019-06-11 11:08:01+00:00            26.0            26.0
# 2019-06-17 10:30:50+00:00            29.0            29.0
# 2019-02-21 11:50:58+00:00            32.0            32.0
# 2019-09-18 11:32:35+00:00            17.0            17.0
#
# [117304 rows x 17 columns]

# %% [markdown]
# c) Exécutez le code ci-dessous qui détermine l'id du restaurant et les dates de la période souhaitée. Ce sont ces paramètres que nous allons rendre sélectionnables grâce aux widgets.

# %%
id_store = 8052
date_debut = "2019-10-01"
date_fin = "2021-12-31"

df_store = df[(df.id_store == id_store) & (df.date_opened >= date_debut) & (df.date_closed < date_fin)]
df_store.shape
# Out:
# (2703, 17)

# %% [markdown]
# d) Changez le code précédent en utilisant deux widgets, un dropdown menu pour choisir le restaurant et un date picker pour choisir la date de début et de fin de la période qu'on souhaite analyser.

# %% [markdown]
# Créez la variable `id_store_dropdown` avec un widget de type Dropdown :

# %%
# Dropdown : menu déroulant avec la liste des restaurants
id_store_dropdown = widgets.Dropdown(
    options=df["id_store"].unique().tolist(),
    value=df["id_store"].unique()[0],
    description="Restaurant :",
    style={"description_width": "initial"},
)

# %%
display(id_store_dropdown)
# Out:
# Dropdown(description='Restaurant :', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965, 6293, 4542), styl…

# %% [markdown]
# Créez la variable `date_debut_picker` avec un widget de type DatePicker :

# %%
# DatePicker : sélection d'une date de début
date_debut_picker = widgets.DatePicker(
    description="Date début :",
    style={"description_width": "initial"},
)

# %%
display(date_debut_picker)
# Out:
# DatePicker(value=None, description='Date début :', step=1, style=DescriptionStyle(description_width='initial')…

# %% [markdown]
# Créez la variable `date_fin_picker` avec un widget de type DatePicker :

# %%
# DatePicker : sélection d'une date de fin
date_fin_picker = widgets.DatePicker(
    description="Date fin :",
    style={"description_width": "initial"},
)

# %%
display(date_fin_picker)
# Out:
# DatePicker(value=None, description='Date fin :', step=1, style=DescriptionStyle(description_width='initial'))

# %% [markdown]
# e) Exécutez le code suivant pour transformer toutes les visualisations réalisées au TP précédent en fonctions

# %%
import plotly.graph_objects as go

def revenue_over_time(df_store):
    df_revenue = df_store[df_store.dim_status=="CLOSED"].resample("D").m_cached_payed.sum()

    fig = px.line(df_revenue,
                  y="m_cached_payed",
                  title="Chiffre d'affaire au cours du temps")
    fig.update_xaxes(
        rangeselector=dict(
            buttons=list([
                dict(count=7, label="Last 7days", step="day", stepmode="backward"),
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    fig.show()

def clients_over_time(df_store):
    df_revenue = df_store[df_store.dim_status=="CLOSED"].resample("D").m_cached_payed.sum()
    df_nb_customer = df_store[df_store.dim_status=="CLOSED"].resample("D")["m_nb_customer"].sum()

    df_average_basket = df_revenue / df_nb_customer

    fig_panier_moyen = go.Scatter(x=df_average_basket.index,
                                  y=df_average_basket,
                                  name="panier moyen",
                                  mode="lines",
                                  line_color="#000000")

    fig = px.bar(df_nb_customer,
                 title="Nombre de clients au cours du temps")
    fig.add_trace(fig_panier_moyen)
    fig.update_xaxes(tickformat="%d/%m/%Y")
    fig.update_xaxes(
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    fig.show()

def best_staff(df_store):
    df_store = df_store.copy()
    # Convertir en string d'abord (sinon on ne peut pas mettre "unknown" dans une colonne float)
    df_store["id_waiter"] = df_store["id_waiter"].astype(str).replace("nan", "unknown")

    df_waiter = df_store.groupby("id_waiter", as_index=False)["m_cached_payed"].sum()

    fig = px.pie(
        df_waiter,
        names='id_waiter',
        values='m_cached_payed',
        color='id_waiter',
        title = 'Répartition des commandes non enregistrées par un serveur'
    )
    fig.update_traces(
        textinfo='percent+label'
    )
    fig.show()

# %% [markdown]
# f) Faîtes intéragir les widgets précédemment créés, via la fonction 'interact', avec la fonction 'display_dash'.
#
# Cette fonction 'display_dash' filtre le dataframe initial en fonction des valeurs précisées dans les trois widgets, et appelle ensuite les visualisations ci-dessus pour les afficher à partir du dataframe filtré.
#
# Vous devez donc, dans cette fonction 'display_dash' :
# - filtrer le dataframe iniitial (df) en fonction des valeurs des widgets id_store_dropdown, date_debut_picker et date_fin_picker
# - appeler les fonctions revenue_over_time, clients_over_time et best_staff

# %%
def display_dash(df, id_store_dropdown, date_debut_picker, date_fin_picker):
    # Attendre que les dates soient sélectionnées
    if date_debut_picker is None or date_fin_picker is None:
        print("Veuillez sélectionner une date de début et une date de fin.")
        return
    # Filtrer sur le restaurant et la période choisie via les widgets
    df_filtered = df[(df["id_store"] == id_store_dropdown)]
    df_filtered = df_filtered[df_filtered["date_opened"] >= str(date_debut_picker)]
    df_filtered = df_filtered[df_filtered["date_closed"] < str(date_fin_picker)]
    # Afficher les 3 graphiques
    revenue_over_time(df_filtered)
    clients_over_time(df_filtered)
    best_staff(df_filtered)

# %%
df = pd.read_csv("Tiller_order_data.csv", low_memory=False)

# Transforme les dates en format datetime
df["date_opened"] = pd.to_datetime(df["date_opened"])
df["date_closed"] = pd.to_datetime(df["date_closed"])

# Mettre en index la date d'ouverture de commande
df = df.set_index(df["date_opened"])

# %%
# Cette cellule est complétée en h) plus bas, après la définition de 'ui' en g)
# → passer directement à g) puis h)

# %% [markdown]
# g) Organisez votre dashboard en utilisant HBox et VBox de la librairie widgets.
#
# Ils permettent de gérer l'agencement des différentes visualisation :
# - placer sur la première ligne le widget : id_store_dropdown
# - placer sur la seconde ligne les widgets date_debut_picker et date_fin_picker

# %%
from ipywidgets import HBox, VBox

# %%
# VBox = empile verticalement, HBox = aligne horizontalement
# Ligne 1 : le dropdown du restaurant
# Ligne 2 : les deux date pickers côte à côte
ui = VBox([
    id_store_dropdown,
    HBox([date_debut_picker, date_fin_picker])
])

# %%
ui
# Out:
# VBox(children=(Dropdown(description='Restaurant :', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965, 62…

# %% [markdown]
# h) utiliser maintenant la fonction ['interactive_output'](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html#More-control-over-the-user-interface:-interactive_output).
# Cette fonction permet d'être plus flexible sur la disposition des widgets.

# %%
# interactive_output connecte les widgets à la fonction display_dash
# Changer un widget relance automatiquement la fonction et met à jour les graphiques
out = interactive_output(
    display_dash,
    {
        "df": fixed(df),
        "id_store_dropdown": id_store_dropdown,
        "date_debut_picker": date_debut_picker,
        "date_fin_picker": date_fin_picker,
    }
)
display(ui, out)
# Out:
# VBox(children=(Dropdown(description='Restaurant :', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965, 62…
# Output()

# %% [markdown]
# i) Vérifiez que tout fonctionne bien en changeant l'id du restaurant et les dates de la période.
# Si tout fonctionne, Bravo vous avez créé votre premier dashboard sous Python !

# %% [markdown]
# # 4) Transformation du notebook en application web avec Voilà

# %% [markdown]
# Maintenant que nous avons l'ensemble des éléments pour notre dashboard utilisateur, nous allons convertir notre notebook en application web pour qu'on puisse l'exécuter en local et pouvoir interragir avec les éléments.

# %% [markdown]
# a) Commencez par installer [Voila](https://github.com/voila-dashboards/voila)

# %%
import sys
# !{sys.executable} -m pip install voila
# Out:
# Requirement already satisfied: voila in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (0.5.11)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (8.8.0)
# Requirement already satisfied: jupyter-core>=4.11.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (5.9.1)
# Requirement already satisfied: jupyter-server<3,>=1.18 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (2.28.0)
# Requirement already satisfied: nbclient>=0.4.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (0.10.4)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (7.17.0)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (5.14.3)
# Requirement already satisfied: websockets>=9.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from voila) (16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-client<9,>=7.4.4->voila) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-client<9,>=7.4.4->voila) (6.5.4)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-server<3,>=1.18->voila) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (3.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbconvert<8,>=6.4.5->voila) (2.19.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (25.1.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-core>=4.11.0->voila) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (25.10.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.18->voila) (2.21.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2026.1.4)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.1)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from terminado>=0.8.3->jupyter-server<3,>=1.18->voila) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.4.0)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/TheWagon/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (2025.3)

# %% [markdown]
# b) Marquez toutes les cellules pour ne garder que les cellules de l'exercice 3, afin de n'afficher que le dashboard de cette partie.
#
# Pour ce faire, vous devrez taggez au préalable les cellules avec un nom de tag. On choisira le tag `hide` dans cet exemple.
#
# Pour cela, cliquez sur "Affichage"-> "Barre d'outil de cellule" -> "Tags"
#
# (Ah... attendez, c'est déjà fait ! On vous fait gagner du temps)

# %% [markdown]
# c) Depuis un terminal, lancez la commande :
# ```
# voila --TagRemovePreprocessor.remove_cell_tags hide ce_notebook.ipynb
#
# cd "20260212 - WIDGETS - Extending Notebooks" && voila --TagRemovePreprocessor.remove_cell_tags hide "td_6_visualisation_enonces_v3.ipynb"
#
# ```

# %% [markdown]
# # 5) Déploiement de la webapp avec ngrok

# %% [markdown]
# On souhaite maintenant pouvoir partager notre webapp sans pour autant la déployer sur serveur sur un autre ordinateur.
#
# Pour cela, nous allons utiliser la librairie ngrok dont la documentation peut être consultée à [cette adresse](https://voila.readthedocs.io/en/stable/deploy.html). Mais nous allons vous guider dans la suite de cette partie.

# %% [markdown]
# a) Installer [ngrok](https://ngrok.com/download)
#
# https://ngrok.com/download

# %% [markdown]
# b) Unzippez l'archive, puis authentifiez vous avec votre token :
#
# ```./ngrok authtoken <token>```

# %% [markdown]
# c) Assurez-vous qu'une webapp voilà est déjà lancée en local (cf : commande voila ci-dessus)

# %% [markdown]
# d) Lancer un tunnel sur le port 8866 :
#
# ```./ngrok http 8866```

# %% [markdown]
# e) Cliquez sur le lien affiché dans le terminal (```Forwarding```).
# Vous pouvez envoyer cette url à votre voisin, il pourra acceder à votre webapp !

# %% [markdown]
# # [Bonus] Déploiement d'une webapp avec Binder
#
# Pour pouvoir utiliser [Binder](https://jupyter.org/binder), il faut au préalable avoir pushé son notebook dans un repo git et avoir rajouté un fichier 'requirements.txt' contenant les librairies nécessaires pour faire tourner votre projet.
#
# Ensuite, il suffit d'aller sur https://mybinder.org/ et :
# - dans 'GitHub', copier coller l'URL de votre projet git
# - dans 'Path to a notebook file (optional)', écrivez 'voila/render/ce_notebook.ipynb' en précisant bien 'URL' au lieu de 'File'. Celà permet de spécifier à Binder qu'il faut directement utiliser Voila pour créer la webapp.
#
# Cliquez ensuite sur 'lauch'. Une image docker de votre projet sera créer grace au fichier 'requirements.txt'. Vous aurez ensuite un lien pour lancer un conteneur docker autonome qui vous permettra d'acceder à votre application web. Pour chaque utilisateur utilisant ce lien, un conteneur docker sera créé.
